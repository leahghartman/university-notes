# %% [markdown]
# # Project 0 -- Curvature Flow

# %% [markdown]
# The purpose of this project is to write code to solve the governing equation for curvature flow:
#
# $$
# \dot{\mathbf{x}} = \frac{x_{2\alpha} x_{1\alpha\alpha} - x_{1\alpha} x_{2\alpha\alpha}}{|\mathbf{x}_\alpha|^3},
# $$
#
# where
#
# We're told to take the initial shape to be:
#
# $$
# \mathbf{x}_0(\alpha) = (4 + \cos{3\alpha})
# \begin{bmatrix}
# \cos{\alpha} \\
# \sin{\alpha}
# \end{bmatrix}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt
